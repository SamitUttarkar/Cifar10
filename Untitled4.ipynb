# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU, ReLU
from tensorflow.keras.layers import Dropout
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
import matplotlib.pyplot as plt
from matplotlib import pyplot
import numpy as np

# %%
(train_images, train_labels), (test_images, test_labels) = datasets .cifar10.load_data()
# first we will normalise the data
train_images, test_images = train_images / 255.0 , test_images / 255

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
plt.imshow(train_images[0])
plt.title(classes[train_labels[0][0]])
# Out:
# Text(0.5, 1.0, 'frog')

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 550,570
# Trainable params: 550,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',
             loss = 'sparse_categorical_crossentropy',
             metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=50, batch_size=64, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/50
# 782/782 [==============================] - 64s 81ms/step - loss: 1.5879 - accuracy: 0.4134 - val_loss: 1.1753 - val_accuracy: 0.5834
# Epoch 2/50
# 782/782 [==============================] - 62s 80ms/step - loss: 1.1139 - accuracy: 0.6039 - val_loss: 0.9448 - val_accuracy: 0.6579
# Epoch 3/50
# 782/782 [==============================] - 62s 80ms/step - loss: 0.9207 - accuracy: 0.6791 - val_loss: 0.7947 - val_accuracy: 0.7214
# Epoch 4/50
# 782/782 [==============================] - 64s 81ms/step - loss: 0.8039 - accuracy: 0.7188 - val_loss: 0.7486 - val_accuracy: 0.7399
# Epoch 5/50
# 782/782 [==============================] - 63s 80ms/step - loss: 0.7273 - accuracy: 0.7475 - val_loss: 0.6931 - val_accuracy: 0.7613
# Epoch 6/50
# 782/782 [==============================] - 66s 84ms/step - loss: 0.6641 - accuracy: 0.7704 - val_loss: 0.6785 - val_accuracy: 0.7663
# Epoch 7/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.6237 - accuracy: 0.7816 - val_loss: 0.6316 - val_accuracy: 0.7801
# Epoch 8/50
# 782/782 [==============================] - 61s 79ms/step - loss: 0.5888 - accuracy: 0.7943 - val_loss: 0.6346 - val_accuracy: 0.7858
# Epoch 9/50
# 782/782 [==============================] - 63s 80ms/step - loss: 0.5597 - accuracy: 0.8031 - val_loss: 0.6064 - val_accuracy: 0.7943
# Epoch 10/50
# 782/782 [==============================] - 63s 81ms/step - loss: 0.5274 - accuracy: 0.8161 - val_loss: 0.6204 - val_accuracy: 0.7902
# Epoch 11/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.5042 - accuracy: 0.8225 - val_loss: 0.6026 - val_accuracy: 0.7988
# Epoch 12/50
# 782/782 [==============================] - 61s 78ms/step - loss: 0.4848 - accuracy: 0.8267 - val_loss: 0.6139 - val_accuracy: 0.7985
# Epoch 13/50
# 782/782 [==============================] - 61s 78ms/step - loss: 0.4682 - accuracy: 0.8355 - val_loss: 0.6096 - val_accuracy: 0.8036
# Epoch 14/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.4436 - accuracy: 0.8430 - val_loss: 0.6076 - val_accuracy: 0.8023
# Epoch 15/50
# 782/782 [==============================] - 62s 80ms/step - loss: 0.4351 - accuracy: 0.8470 - val_loss: 0.6096 - val_accuracy: 0.8047
# Epoch 16/50
# 782/782 [==============================] - 63s 81ms/step - loss: 0.4219 - accuracy: 0.8520 - val_loss: 0.6415 - val_accuracy: 0.7996
# Epoch 17/50
# 782/782 [==============================] - 63s 81ms/step - loss: 0.4150 - accuracy: 0.8528 - val_loss: 0.6080 - val_accuracy: 0.8071
# Epoch 18/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.3927 - accuracy: 0.8601 - val_loss: 0.6235 - val_accuracy: 0.8109
# Epoch 19/50
# 782/782 [==============================] - 63s 81ms/step - loss: 0.3882 - accuracy: 0.8624 - val_loss: 0.6132 - val_accuracy: 0.8078
# Epoch 20/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.3756 - accuracy: 0.8670 - val_loss: 0.6357 - val_accuracy: 0.8031
# Epoch 21/50
# 782/782 [==============================] - 63s 80ms/step - loss: 0.3707 - accuracy: 0.8692 - val_loss: 0.6518 - val_accuracy: 0.8073
# Epoch 22/50
# 782/782 [==============================] - 61s 78ms/step - loss: 0.3582 - accuracy: 0.8752 - val_loss: 0.6236 - val_accuracy: 0.8081
# Epoch 23/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.3489 - accuracy: 0.8770 - val_loss: 0.6196 - val_accuracy: 0.8197
# Epoch 24/50
# 782/782 [==============================] - 64s 81ms/step - loss: 0.3490 - accuracy: 0.8771 - val_loss: 0.6089 - val_accuracy: 0.8188
# Epoch 25/50
# 782/782 [==============================] - 61s 78ms/step - loss: 0.3372 - accuracy: 0.8805 - val_loss: 0.6244 - val_accuracy: 0.8170
# Epoch 26/50
# 782/782 [==============================] - 61s 79ms/step - loss: 0.3317 - accuracy: 0.8828 - val_loss: 0.6345 - val_accuracy: 0.8151
# Epoch 27/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.3312 - accuracy: 0.8836 - val_loss: 0.6604 - val_accuracy: 0.8085
# Epoch 28/50
# 782/782 [==============================] - 62s 80ms/step - loss: 0.3267 - accuracy: 0.8843 - val_loss: 0.6419 - val_accuracy: 0.8157
# Epoch 29/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.3178 - accuracy: 0.8872 - val_loss: 0.6467 - val_accuracy: 0.8165
# Epoch 30/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.3140 - accuracy: 0.8889 - val_loss: 0.6615 - val_accuracy: 0.8180
# Epoch 31/50
# 782/782 [==============================] - 61s 78ms/step - loss: 0.3125 - accuracy: 0.8906 - val_loss: 0.6495 - val_accuracy: 0.8169
# Epoch 32/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.3058 - accuracy: 0.8929 - val_loss: 0.6515 - val_accuracy: 0.8173
# Epoch 33/50
# 782/782 [==============================] - 62s 80ms/step - loss: 0.3040 - accuracy: 0.8928 - val_loss: 0.6259 - val_accuracy: 0.8211
# Epoch 34/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.2938 - accuracy: 0.8975 - val_loss: 0.6233 - val_accuracy: 0.8261
# Epoch 35/50
# 782/782 [==============================] - 61s 79ms/step - loss: 0.2904 - accuracy: 0.8986 - val_loss: 0.6409 - val_accuracy: 0.8199
# Epoch 36/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.2929 - accuracy: 0.8979 - val_loss: 0.6808 - val_accuracy: 0.8160
# Epoch 37/50
# 782/782 [==============================] - 67s 86ms/step - loss: 0.2837 - accuracy: 0.9005 - val_loss: 0.6483 - val_accuracy: 0.8213
# Epoch 38/50
# 782/782 [==============================] - 80s 103ms/step - loss: 0.2817 - accuracy: 0.9014 - val_loss: 0.6667 - val_accuracy: 0.8151
# Epoch 39/50
# 782/782 [==============================] - 66s 85ms/step - loss: 0.2767 - accuracy: 0.9037 - val_loss: 0.6561 - val_accuracy: 0.8246
# Epoch 40/50
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2812 - accuracy: 0.9022 - val_loss: 0.6668 - val_accuracy: 0.8198
# Epoch 41/50
# 782/782 [==============================] - 64s 82ms/step - loss: 0.2782 - accuracy: 0.9035 - val_loss: 0.7036 - val_accuracy: 0.8144
# Epoch 42/50
# 782/782 [==============================] - 62s 80ms/step - loss: 0.2732 - accuracy: 0.9037 - val_loss: 0.6647 - val_accuracy: 0.8220
# Epoch 43/50
# 782/782 [==============================] - 61s 79ms/step - loss: 0.2727 - accuracy: 0.9051 - val_loss: 0.6491 - val_accuracy: 0.8253
# Epoch 44/50
# 782/782 [==============================] - 63s 80ms/step - loss: 0.2701 - accuracy: 0.9054 - val_loss: 0.6728 - val_accuracy: 0.8162
# Epoch 45/50
# 782/782 [==============================] - 61s 79ms/step - loss: 0.2661 - accuracy: 0.9083 - val_loss: 0.6781 - val_accuracy: 0.8194
# Epoch 46/50
# 782/782 [==============================] - 63s 80ms/step - loss: 0.2620 - accuracy: 0.9077 - val_loss: 0.6611 - val_accuracy: 0.8215
# Epoch 47/50
# 782/782 [==============================] - 62s 80ms/step - loss: 0.2603 - accuracy: 0.9092 - val_loss: 0.6971 - val_accuracy: 0.8217
# Epoch 48/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.2695 - accuracy: 0.9043 - val_loss: 0.6698 - val_accuracy: 0.8172
# Epoch 49/50
# 782/782 [==============================] - 61s 78ms/step - loss: 0.2571 - accuracy: 0.9094 - val_loss: 0.7100 - val_accuracy: 0.8137
# Epoch 50/50
# 782/782 [==============================] - 62s 79ms/step - loss: 0.2603 - accuracy: 0.9103 - val_loss: 0.7251 - val_accuracy: 0.8124

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 4s - loss: 0.7251 - accuracy: 0.8124 - 4s/epoch - 14ms/step

# %%
print(test_acc)
# Out:
# 0.8123999834060669

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.ylim(0.80, 0.88)
plt.legend(['train','test'], loc = 'upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0.4,1)
plt.legend(['train','test'], loc = 'upper left')
plt.show()

# %%
pyplot.subplot(211)
pyplot.title('Cross Entropy Loss')
pyplot.plot(history.history['loss'], color='blue', label='train')
pyplot.plot(history.history['val_loss'], color='orange', label='test')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'])
# plot accuracy
pyplot.subplot(212)
pyplot.title('Classification Accuracy')
pyplot.plot(history.history['accuracy'], color='blue', label='train')
pyplot.plot(history.history['val_accuracy'], color='orange', label='test')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc = 'lower right')
plt.tight_layout()
